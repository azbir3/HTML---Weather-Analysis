# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
data_file = "Resources/cityData.csv"

# Read Purchasing File and store into Pandas data frame
cityData = pd.read_csv(data_file)
cityData.head(5)
# Out:
#    City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0   rovaniemi          75      FI  1567691023        76  66.50
# 1        1   busselton           0      AU  1567691024        59 -33.64
# 2        2  villanueva           0      HN  1567691024        83  15.32
# 3        3   chengzihe          98      CN  1567691024        95  45.35
# 4        4     goundam          15      ML  1567691025        25  16.42
#
#       Lng  Max Temp  Wind Speed
# 0   25.72     53.60        8.05
# 1  115.35     44.01       10.69
# 2  -87.99     84.99        5.82
# 3  131.00     62.15        4.16
# 4   -3.66    101.93       11.63

# %%
# File to Load (Remember to Change These)
data_file = "Resources/cityData.csv"

# Read Purchasing File and store into Pandas data frame
cityData = pd.read_csv(data_file, index_col=False)
cityData.head(5)
# Out:
#    City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0   rovaniemi          75      FI  1567691023        76  66.50
# 1        1   busselton           0      AU  1567691024        59 -33.64
# 2        2  villanueva           0      HN  1567691024        83  15.32
# 3        3   chengzihe          98      CN  1567691024        95  45.35
# 4        4     goundam          15      ML  1567691025        25  16.42
#
#       Lng  Max Temp  Wind Speed
# 0   25.72     53.60        8.05
# 1  115.35     44.01       10.69
# 2  -87.99     84.99        5.82
# 3  131.00     62.15        4.16
# 4   -3.66    101.93       11.63

# %%
# render dataframe as html
html = cityData.to_html(index=False)
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>rovaniemi</td>
#       <td>75</td>
#       <td>FI</td>
#       <td>1567691023</td>
#       <td>76</td>
#       <td>66.50</td>
#       <td>25.72</td>
#       <td>53.60</td>
#       <td>8.05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>busselton</td>
#       <td>0</td>
#       <td>AU</td>
#       <td>1567691024</td>
#       <td>59</td>
#       <td>-33.64</td>
#       <td>115.35</td>
#       <td>44.01</td>
#       <td>10.69</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>villanueva</td>
#       <td>0</td>
#       <td>HN</td>
#       <td>1567691024</td>
# ...

# %%
#write html to file
text_file = open("Resources/CityData.html", "w")
text_file.write(html)
text_file.close()
